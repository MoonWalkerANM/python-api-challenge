# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests



# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a9997b55-d3b2-4faa-a6f4-6aa93f51d55d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"095c87ec-815a-4b08-9984-9b59be9ee952":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"7fc330757b9142268c8b5028033d3034","client_comm_id":"8884f395153743c19ee3dff2e7ef27af"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"095c87ec-815a-4b08-9984-9b59be9ee952","roots":{"p1002":"a9997b55-d3b2-4faa-a6f4-6aa93f51d55d"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                         City      Lat       Lng  Max Temp  \
# 0        0                    jamestown  42.0970  -79.2353     15.95
# 1        1                        ancud -41.8697  -73.8203      8.92
# 2        2  edinburgh of the seven seas -37.0676  -12.3116     18.61
# 3        3                       albany  42.6001  -73.9662     15.33
# 4        4                     rongelap  11.1635  166.8941     26.79
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        98          75        6.69      US  1712883639
# 1        73           0        2.40      CL  1712883617
# 2        92           9        7.68      SH  1712883878
# 3        80         100        1.34      US  1712883645
# 4        77         100        8.80      MH  1712883878

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600
)
   

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities = city_data_df[
    (city_data_df['Max Temp'] < 27) & 
    (city_data_df['Max Temp'] > 21) & 
    (city_data_df['Wind Speed'] < 4.5)
]
# Drop any rows with null values
ideal_cities_cleaned = ideal_cities.dropna()

# Display sample data
ideal_cities_cleaned.head()
# Out:
#     City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 6         6  wailua homesteads  22.0669 -159.3780     23.75        86
# 9         9              yunfu  22.9306  112.0373     26.26        77
# 12       12            kisanga  -7.4362   37.7034     23.79        95
# 23       23           belmonte -15.8631  -38.8828     25.89        84
# 27       27              alamo  20.9167  -97.6833     26.80        61
#
#     Cloudiness  Wind Speed Country        Date
# 6          100        3.04      US  1712883778
# 9           53        1.01      CN  1712883851
# 12          49        0.79      TZ  1712883881
# 23          12        2.27      BR  1712883763
# 27          17        4.13      MX  1712883885

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_cleaned[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel'] = ''

# Display sample data
hotel_df.head()
# Out:
#                  City Country      Lat       Lng  Humidity Hotel
# 6   wailua homesteads      US  22.0669 -159.3780        86
# 9               yunfu      CN  22.9306  112.0373        77
# 12            kisanga      TZ  -7.4362   37.7034        95
# 23           belmonte      BR -15.8631  -38.8828        84
# 27              alamo      MX  20.9167  -97.6833        61

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.guest_house",  
    "radius": radius,  
    "apiKey": geoapify_key
}


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# wailua homesteads - nearest hotel: No hotel found
# yunfu - nearest hotel: No hotel found
# kisanga - nearest hotel: No hotel found
# belmonte - nearest hotel: No hotel found
# alamo - nearest hotel: No hotel found
# harper - nearest hotel: No hotel found
# port mathurin - nearest hotel: Résidence Véronia
# sao vicente - nearest hotel: Pousada de Santos
# sambava - nearest hotel: No hotel found
# conde - nearest hotel: Bandeirante
# axim - nearest hotel: No hotel found
# puerto ayora - nearest hotel: Gecko Guesthouse
# san patricio - nearest hotel: No hotel found
# san-pedro - nearest hotel: SRO MOH114
# tura - nearest hotel: No hotel found
# tolanaro - nearest hotel: Chez Jacqueline's
# touros - nearest hotel: No hotel found
# carutapera - nearest hotel: No hotel found
# saint-joseph - nearest hotel: L'Arpège Austral
# dostpur - nearest hotel: No hotel found
# boyolangu - nearest hotel: Wisma Minthul
# copala - nearest hotel: No hotel found
# remire-montjoly - nearest hotel: No hotel found
# allende - nearest hotel: No hotel found
# itoman - nearest hotel: 民宿那覇
# hawaiian paradise park - nearest hotel: No hotel found
# tefe - nearest hotel: Pousada Amazonas
# kapa'a - nearest hotel: No hotel found
# bam - nearest hotel: نخل و نارنج
# vinukonda - nearest hotel: No hotel found
# devgadh bariya - nearest hotel: No hotel found
# chilca - nearest hotel: Playa las Ninfas
# sungai penuh - nearest hotel: No hotel found
# la'ie - nearest hotel: Jones’ Beach House
# kone - nearest hotel: No hotel found
# gunjur - nearest hotel: Gunjur Project
# lubuklinggau - nearest hotel: No hotel found
# yanam - nearest hotel: No hotel found
# lobito - nearest hotel: Casa de Passagem do Porto do Lobito
# balikpapan - nearest hotel: Kamilah Kost
# cabo san lucas - nearest hotel: Cabanas at Brisas Del Pacífico
# canutama - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropicaloc
# ar ruways - nearest hotel: APPLE FOOD STUFF HOUSE CARAVAN
# lihue - nearest hotel: No hotel found
# tucuma - nearest hotel: No hotel found
# radaur - nearest hotel: No hotel found
# kalmunai - nearest hotel: No hotel found
# mana - nearest hotel: Gîte des Terres Rouges
# prabumulih - nearest hotel: No hotel found
# barra do bugres - nearest hotel: No hotel found
# puerto baquerizo moreno - nearest hotel: Casa D' Cristhi
# boende - nearest hotel: No hotel found
# sao paulo de olivenca - nearest hotel: No hotel found
# tucupita - nearest hotel: No hotel found
# hadibu - nearest hotel: No hotel found
# kiama - nearest hotel: Beach
# gwadar - nearest hotel: No hotel found
# praya - nearest hotel: Jajó
# garoowe - nearest hotel: No hotel found
# tegueste - nearest hotel: Finca Los Geranios
# dzilam gonzalez - nearest hotel: No hotel found
# mehekar - nearest hotel: No hotel found
# katsuren-haebaru - nearest hotel: Ma Mezon
# coahuayana de hidalgo - nearest hotel: No hotel found
# magalia - nearest hotel: No hotel found
# bahia honda - nearest hotel: No hotel found
# lang son - nearest hotel: No hotel found
# lianzhou - nearest hotel: No hotel found
# kharsia - nearest hotel: No hotel found
# luba - nearest hotel: No hotel found
# kihurio - nearest hotel: No hotel found
# santa luzia - nearest hotel: No hotel found
# nova vicosa - nearest hotel: Pousada Vila Peruípe
# hengchun - nearest hotel: 8door
# margherita - nearest hotel: No hotel found
# porto da folha - nearest hotel: No hotel found
# port douglas - nearest hotel: Mai Tai resort
# rio preto da eva - nearest hotel: No hotel found
# bria - nearest hotel: No hotel found
# kariba - nearest hotel: Warthogs Bush Camp
# ciudad lazaro cardenas - nearest hotel: No hotel found
# churachandpur - nearest hotel: No hotel found
# lompoc - nearest hotel: Alano Club
# luanda - nearest hotel: No hotel found
# la troncal - nearest hotel: Hostal Fenix Inn
# namibe - nearest hotel: Pensão Delta do Deserto
# riberalta - nearest hotel: No hotel found
# al harithah - nearest hotel: No hotel found
# al hufuf - nearest hotel: No hotel found
# yamba - nearest hotel: No hotel found
# santa cruz - nearest hotel: No hotel found
# santana - nearest hotel: Ana Castelo
# najran - nearest hotel: No hotel found
# huarmey - nearest hotel: Hospedaje La Posada de Huarmey
# aroma - nearest hotel: No hotel found
# sao miguel do araguaia - nearest hotel: No hotel found
# chisec - nearest hotel: No hotel found
# bogra - nearest hotel: বগুড়া সার্কিট হাউস
# buon ma thuot - nearest hotel: Nhà khách tỉnh Đăk Lăk
# salem - nearest hotel: My house
# mancio lima - nearest hotel: No hotel found
# turabah - nearest hotel: No hotel found
# maragogi - nearest hotel: Pousada LuMar
# tionk essil - nearest hotel: No hotel found
# hilo - nearest hotel: Hilo Bay Oceanfront Bed and Breakfast
#                   City Country      Lat       Lng  Humidity  \
# 6    wailua homesteads      US  22.0669 -159.3780        86
# 9                yunfu      CN  22.9306  112.0373        77
# 12             kisanga      TZ  -7.4362   37.7034        95
# 23            belmonte      BR -15.8631  -38.8828        84
# 27               alamo      MX  20.9167  -97.6833        61
# ..                 ...     ...      ...       ...       ...
# 528        mancio lima      BR  -7.6142  -72.8958        95
# 539            turabah      SA  21.2141   41.6331        50
# 551           maragogi      BR  -9.0122  -35.2225        83
# 552        tionk essil      SN  12.7856  -16.5217        66
# 558               hilo      US  19.7297 -155.0900        95
#
#                                      Hotel
# 6                           No hotel found
# 9                           No hotel found
# 12                          No hotel found
# 23                          No hotel found
# 27                          No hotel found
# ..                                     ...
# 528                         No hotel found
# 539                         No hotel found
# 551                          Pousada LuMar
# 552                         No hotel found
# 558  Hilo Bay Oceanfront Bed and Breakfast
#
# [106 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot1 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    hover_cols=['Lat', 'Lng', 'City', 'Humidity', 'Hotel', 'Country']
)

# Display the map
map_plot1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel,Country)
