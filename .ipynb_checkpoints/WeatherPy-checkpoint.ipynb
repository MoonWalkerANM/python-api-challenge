# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 580

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 585

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
  #  city_url = f"{url}?q={city}&appid={weather_api_key}"
    city_url = url + "&q=" + city
  
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | ancud
# Processing Record 3 of Set 1 | edinburgh of the seven seas
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | saratamata
# City not found. Skipping...
# Processing Record 6 of Set 1 | rongelap
# Processing Record 7 of Set 1 | hamilton
# Processing Record 8 of Set 1 | wailua homesteads
# Processing Record 9 of Set 1 | tralee
# Processing Record 10 of Set 1 | atafu village
# Processing Record 11 of Set 1 | yunfu
# Processing Record 12 of Set 1 | portland
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | kisanga
# Processing Record 15 of Set 1 | bodo
# Processing Record 16 of Set 1 | galliano
# Processing Record 17 of Set 1 | newman
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | patnanungan
# Processing Record 20 of Set 1 | grytviken
# Processing Record 21 of Set 1 | poltavka
# Processing Record 22 of Set 1 | port-aux-francais
# Processing Record 23 of Set 1 | enewetak
# Processing Record 24 of Set 1 | college
# Processing Record 25 of Set 1 | belmonte
# Processing Record 26 of Set 1 | flying fish cove
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | talnakh
# Processing Record 29 of Set 1 | alamo
# Processing Record 30 of Set 1 | port lincoln
# Processing Record 31 of Set 1 | batam
# City not found. Skipping...
# Processing Record 32 of Set 1 | st. john's
# Processing Record 33 of Set 1 | dudinka
# Processing Record 34 of Set 1 | abu al matamir
# Processing Record 35 of Set 1 | yuzhno-kurilsk
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | lorengau
# Processing Record 39 of Set 1 | flin flon
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | harper
# Processing Record 42 of Set 1 | fort bragg
# Processing Record 43 of Set 1 | port mathurin
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | isafjordur
# Processing Record 46 of Set 1 | fale old settlement
# Processing Record 47 of Set 1 | qaqortoq
# Processing Record 48 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 49 of Set 1 | adamstown
# Processing Record 50 of Set 1 | bilibino
# Processing Record 0 of Set 2 | port elizabeth
# Processing Record 1 of Set 2 | walvis bay
# Processing Record 2 of Set 2 | hanceville
# Processing Record 3 of Set 2 | twon-brass
# Processing Record 4 of Set 2 | bergamo
# Processing Record 5 of Set 2 | happy valley-goose bay
# Processing Record 6 of Set 2 | gao
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | stanley
# Processing Record 10 of Set 2 | sao vicente
# Processing Record 11 of Set 2 | east end
# Processing Record 12 of Set 2 | puerto natales
# Processing Record 13 of Set 2 | san andres
# Processing Record 14 of Set 2 | sambava
# Processing Record 15 of Set 2 | sturgeon bay
# Processing Record 16 of Set 2 | pulandian
# Processing Record 17 of Set 2 | klyuchi
# Processing Record 18 of Set 2 | bel ombre
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | conde
# Processing Record 21 of Set 2 | cerea
# Processing Record 22 of Set 2 | axim
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | polovinnoye
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | nebbi
# Processing Record 28 of Set 2 | sitka
# Processing Record 29 of Set 2 | palikir - national government center
# Processing Record 30 of Set 2 | okhotsk
# Processing Record 31 of Set 2 | valle de la pascua
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | anadyr
# Processing Record 34 of Set 2 | chernyshevskiy
# Processing Record 35 of Set 2 | kaiapoi
# Processing Record 36 of Set 2 | lakatoro
# Processing Record 37 of Set 2 | nikolayevsk-on-amure
# Processing Record 38 of Set 2 | hobyo
# Processing Record 39 of Set 2 | necochea
# Processing Record 40 of Set 2 | san-pedro
# Processing Record 41 of Set 2 | tura
# Processing Record 42 of Set 2 | tolanaro
# Processing Record 43 of Set 2 | ilulissat
# Processing Record 44 of Set 2 
of Set 4 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 4 | whitehorse
# Processing Record 36 of Set 4 | la'ie
# Processing Record 37 of Set 4 | west island
# Processing Record 38 of Set 4 | kone
# Processing Record 39 of Set 4 | invercargill
# Processing Record 40 of Set 4 | haiku-pauwela
# Processing Record 41 of Set 4 | tapa
# Processing Record 42 of Set 4 | gadzhiyevo
# Processing Record 43 of Set 4 | kloulklubed
# Processing Record 44 of Set 4 | iskateley
# Processing Record 45 of Set 4 | mujiayingzi
# Processing Record 46 of Set 4 | we
# City not found. Skipping...
# Processing Record 47 of Set 4 | tsiombe
# Processing Record 48 of Set 4 | turpan
# Processing Record 49 of Set 4 | gunjur
# Processing Record 0 of Set 5 | filadelfia
# Processing Record 1 of Set 5 | lautoka
# Processing Record 2 of Set 5 | avarua
# Processing Record 3 of Set 5 | devinuwara
# City not found. Skipping...
# Processing Record 4 of Set 5 | vorgashor
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | tavda
# Processing Record 7 of Set 5 | koutiala
# Processing Record 8 of Set 5 | namanga
# Processing Record 9 of Set 5 | rabo de peixe
# Processing Record 10 of Set 5 | la passe
# Processing Record 11 of Set 5 | lubuklinggau
# Processing Record 12 of Set 5 | nuuk
# Processing Record 13 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 14 of Set 5 | yanam
# Processing Record 15 of Set 5 | metlili chaamba
# Processing Record 16 of Set 5 | mount gambier
# Processing Record 17 of Set 5 | lobito
# Processing Record 18 of Set 5 | saudarkrokur
# Processing Record 19 of Set 5 | balikpapan
# Processing Record 20 of Set 5 | fort st. john
# Processing Record 21 of Set 5 | nyakahanga
# Processing Record 22 of Set 5 | savanna-la-mar
# Processing Record 23 of Set 5 | cabo san lucas
# Processing Record 24 of Set 5 | canutama
# Processing Record 25 of Set 5 | cockburn town
# Processing Record 26 of Set 5 | saint-pierre
# Processing Record 27 of Set 5 | geraldton
# Processing Record 28 of Set 5 | beledweyne
# Processing Record 29 of Set 5 | fortaleza
# Processing Record 30 of Set 5 | kati
# Processing Record 31 of Set 5 | ar ruways
# Processing Record 32 of Set 5 | kuusamo
# Processing Record 33 of Set 5 | santiago de chuco
# Processing Record 34 of Set 5 | barrouallie
# Processing Record 35 of Set 5 | chemolgan
# Processing Record 36 of Set 5 | lihue
# Processing Record 37 of Set 5 | kencong
# Processing Record 38 of Set 5 | akureyri
# Processing Record 39 of Set 5 | kenora
# Processing Record 40 of Set 5 | muriti
# Processing Record 41 of Set 5 | guasdualito
# Processing Record 42 of Set 5 | xilin hot
# Processing Record 43 of Set 5 | lata
# Processing Record 44 of Set 5 | polyarnyy
# Processing Record 45 of Set 5 | tucuma
# Processing Record 46 of Set 5 | vilyuchinsk
# Processing Record 47 of Set 5 | faya-largeau
# Processing Record 48 of Set 5 | alpena
# Processing Record 49 of Set 5 | mbinga
# Processing Record 0 of Set 6 | radaur
# Processing Record 1 of Set 6 | sinop
# Processing Record 2 of Set 6 | rouissat
# Processing Record 3 of Set 6 | dhromolaxia
# Processing Record 4 of Set 6 | murzuq
# Processing Record 5 of Set 6 | duong dong
# Processing Record 6 of Set 6 | saipan
# Processing Record 7 of Set 6 | aoulef
# Processing Record 8 of Set 6 | popondetta
# Processing Record 9 of Set 6 | takamaka
# City not found. Skipping...
# Processing Record 10 of Set 6 | kalmunai
# Processing Record 11 of Set 6 | sinabang
# Processing Record 12 of Set 6 | vuktyl
# Processing Record 13 of Set 6 | zelenogorskiy
# Processing Record 14 of Set 6 | quang ngai
# Processing Record 15 of Set 6 | pisco
# Processing Record 16 of Set 6 | northam
# Processing Record 17 of Set 6 | uturoa
# Processing Record 18 of Set 6 | villa regina
# Processing Record 19 of Set 6 | tromso
# Processing Record 20 of Set 6 | mana
# Processing Record 21 of Set 6 | lebu
# Processing Record 22 of Set 6 | prabumulih
# Processing Record 23 of Set 6 | port pirie
# Processing Record 24 of Set 6 | barra do bugres
# Processing Record 25 of Set 6 | luderitz
# Processing Record 26 of Set 6 | puerto ayacucho
# Processing Record 27 of Set 6 | cooma
# Processing Record 28 of Set 6 | knysna
# Processing Record 29 of Set 6 | divnogorsk
# Processing Record 30 of Set 6 | pitimbu
# Processing Record 31 of Set 6 | puerto baquerizo moreno
# Processing Record 32 of Set 6 | zhosaly
# Processing Record 33 of Set 6 | boende
# Processing Record 34 of Set 6 | guerrero negro
# Processing Record 35 of Set 6 | jayapura
# Processing Record 36 of Set 6 | keflavik
# Processing Record 37 of Set 6 | the bottom
# Processing Record 38 of Set 6 | dolzhanskaya
# Processing Record 39 of Set 6 | mitchell
# Processing Record 40 of Set 6 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 41 of Set 6 | sungho 1-tong
# Processing Record 42 of Set 6 | sosnovo-ozerskoye
# Processing Record 43 of Set 6 | bardai
# Processing Record 44 of Set 6 | sao paulo de olivenca
# Processing Record 45 of Set 6 | pyhajarvi
# Processing Record 46 of Set 6 | estevan
# Processing Record 47 of Set 6 | brainerd
# Processing Record 48 of Set 6 | weno
# Processing Record 49 of Set 6 | petawawa
# Processing Record 0 of Set 7 | umm kaddadah
# Processing Record 1 of Set 7 | greymouth
# Processing Record 2 of Set 7 | tucupita
# Processing Record 3 of Set 7 | catacaos
# Processing Record 4 of Set 7 | huron
# Processing Record 5 of Set 7 | skowhegan
# Processing Record 6 of Set 7 | ribadesella
# Processing Record 7 of Set 7 | nova sintra
# Processing Record 8 of Set 7 | kostroma
# Processing Record 9 of Set 7 | ribeira grande
# Processing Record 10 of Set 7 | margaret river
# Processing Record 11 of Set 7 | kristiansund
# Processing Record 12 of Set 7 | sisimiut
# Processing Record 13 of Set 7 | howard springs
# Processing Record 14 of Set 7 | hadibu
# Processing Record 15 of Set 7 | bodaybo
# Processing Record 16 of Set 7 | catriel
# Processing Record 17 of Set 7 | yokadouma
# Processing Record 18 of Set 7 | merizo village
# Processing Record 19 of Set 7 | fernie
# Processing Record 20 of Set 7 | nookat
# City not found. Skipping...
# Processing Record 21 of Set 7 | ulladulla
# Processing Record 22 of Set 7 | sao tome
# Processing Record 23 of Set 7 | thunder bay
# Processing Record 24 of Set 7 | nuku'alofa
# Processing Record 25 of Set 7 | kalisz
# Processing Record 26 of Set 7 | quellon
# Processing Record 3 of Set 9 | katsuren-haebaru
# Processing Record 4 of Set 9 | shimoda
# Processing Record 5 of Set 9 | coahuayana de hidalgo
# Processing Record 6 of Set 9 | nishifukuma
# Processing Record 7 of Set 9 | kailua-kona
# Processing Record 8 of Set 9 | phra phutthabat
# Processing Record 9 of Set 9 | keyser
# Processing Record 10 of Set 9 | borujen
# Processing Record 11 of Set 9 | horta
# Processing Record 12 of Set 9 | eyl
# Processing Record 13 of Set 9 | gallup
# Processing Record 14 of Set 9 | bikenibeu village
# Processing Record 15 of Set 9 | al bawiti
# Processing Record 16 of Set 9 | ceeldheer
# Processing Record 17 of Set 9 | sudak
# Processing Record 18 of Set 9 | magalia
# Processing Record 19 of Set 9 | songea
# Processing Record 20 of Set 9 | broome
# Processing Record 21 of Set 9 | pohang
# Processing Record 22 of Set 9 | tumut
# Processing Record 23 of Set 9 | balezino
# Processing Record 24 of Set 9 | nizhnesortymskiy
# Processing Record 25 of Set 9 | tari
# Processing Record 26 of Set 9 | sur
# Processing Record 27 of Set 9 | gafour
# Processing Record 28 of Set 9 | papao
# Processing Record 29 of Set 9 | bahia honda
# Processing Record 30 of Set 9 | kuloy
# Processing Record 31 of Set 9 | grand falls-windsor
# Processing Record 32 of Set 9 | isangel
# Processing Record 33 of Set 9 | villa berthet
# Processing Record 34 of Set 9 | al jawf
# Processing Record 35 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 36 of Set 9 | camacupa
# Processing Record 37 of Set 9 | prince george
# Processing Record 38 of Set 9 | burang
# Processing Record 39 of Set 9 | dickinson
# Processing Record 40 of Set 9 | san pedro pochutla
# Processing Record 41 of Set 9 | jibou
# Processing Record 42 of Set 9 | taulaga
# Processing Record 43 of Set 9 | cove
# Processing Record 44 of Set 9 | lang son
# Processing Record 45 of Set 9 | lianzhou
# Processing Record 46 of Set 9 | cill airne
# Processing Record 47 of Set 9 | oroqen zizhiqi
# Processing Record 48 of Set 9 | kharsia
# Processing Record 49 of Set 9 | waynesboro
# Processing Record 0 of Set 10 | ronne
# Processing Record 1 of Set 10 | beloyarskiy
# Processing Record 2 of Set 10 | luba
# Processing Record 3 of Set 10 | kihurio
# Processing Record 4 of Set 10 | ardakan
# Processing Record 5 of Set 10 | zaragoza
# Processing Record 6 of Set 10 | santa luzia
# Processing Record 7 of Set 10 | port blair
# Processing Record 8 of Set 10 | san antonio de pale
# Processing Record 9 of Set 10 | salym
# Processing Record 10 of Set 10 | nova vicosa
# Processing Record 11 of Set 10 | margate
# Processing Record 12 of Set 10 | hengchun
# Processing Record 13 of Set 10 | bandarbeyla
# Processing Record 14 of Set 10 | margherita
# Processing Record 15 of Set 10 | argo
# Processing Record 16 of Set 10 | porto da folha
# Processing Record 17 of Set 10 | port douglas
# Processing Record 18 of Set 10 | bizerte
# Processing Record 19 of Set 10 | rio preto da eva
# Processing Record 20 of Set 10 | bria
# Processing Record 21 of Set 10 | hola
# Processing Record 22 of Set 10 | dongkan
# Processing Record 23 of Set 10 | lugovoye
# Processing Record 24 of Set 10 | griffith
# Processing Record 25 of Set 10 | pibor
# City not found. Skipping...
# Processing Record 26 of Set 10 | pangody
# Processing Record 27 of Set 10 | kariba
# Processing Record 28 of Set 10 | la sarre
# Processing Record 29 of Set 10 | mersa matruh
# Processing Record 30 of Set 10 | lincheng
# Processing Record 31 of Set 10 | neiafu
# Processing Record 32 of Set 10 | basco
# Processing Record 33 of Set 10 | keene
# Processing Record 34 of Set 10 | ciudad lazaro cardenas
# Processing Record 35 of Set 10 | marsh harbour
# Processing Record 36 of Set 10 | churachandpur
# Processing Record 37 of Set 10 | puerto armuelles
# Processing Record 38 of Set 10 | azadshahr
# Processing Record 39 of Set 10 | koysinceq
# Processing Record 40 of Set 10 | mejit
# Processing Record 41 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 42 of Set 10 | naze
# Processing Record 43 of Set 10 | salinopolis
# Processing Record 44 of Set 10 | lompoc
# Processing Record 45 of Set 10 | luanda
# Processing Record 46 of Set 10 | lodwar
# Processing Record 47 of Set 10 | la troncal
# Processing Record 48 of Set 10 | namibe
# Processing Record 49 of Set 10 | riberalta
# Processing Record 0 of Set 11 | queenstown
# Processing Record 1 of Set 11 | tahe
# Processing Record 2 of Set 11 | hasaki
# Processing Record 3 of Set 11 | mayya
# Processing Record 4 of Set 11 | sabang
# Processing Record 5 of Set 11 | al harithah
# Processing Record 6 of Set 11 | diffa
# Processing Record 7 of Set 11 | aykhal
# Processing Record 8 of Set 11 | plettenberg bay
# Processing Record 9 of Set 11 | wotho
# Processing Record 10 of Set 11 | listowel
# Processing Record 11 of Set 11 | carnarvon
# Processing Record 12 of Set 11 | tidjikja
# Processing Record 13 of Set 11 | mahdia
# Processing Record 14 of Set 11 | al hufuf
# Processing Record 15 of Set 11 | selma
# Processing Record 16 of Set 11 | yamba
# Processing Record 17 of Set 11 | svetlyy
# Processing Record 18 of Set 11 | fuglafjordur
# Processing Record 19 of Set 11 | yerofey pavlovich
# Processing Record 20 of Set 11 | larache
# Processing Record 21 of Set 11 | santa cruz
# Processing Record 22 of Set 11 | santana
# Processing Record 23 of Set 11 | elmendorf air force base
# City not found. Skipping...
# Processing Record 24 of Set 11 | najran
# Processing Record 25 of Set 11 | ruza
# Processing Record 26 of Set 11 | tenkodogo
# Processing Record 27 of Set 11 | cannonvale
# Processing Record 28 of Set 11 | huarmey
# Processing Record 29 of Set 11 | qapqal
# City not found. Skipping...
# Processing Record 30 of Set 11 | torghay
# Processing Record 31 of Set 11 | aroma
# Processing Record 32 of Set 11 | nouadhibou
# Processing Record 33 of Set 11 | sao miguel do araguaia
# Processing Record 34 of Set 11 | nemuro
# Processing Record 35 of Set 11 | vanimo
# Processing Record 36 of Set 11 | adrar
# Processing Record 37 of Set 11 | singkawang
# Processing Record 38 of Set 11 | shenjiamen
# Processing Record 39 of Set 11 | belaya kholunitsa
# Processing Record 40 of Set 11 | pochinok
# Processing Record 41 of Set 11 | kaa-khem
# Processing Record 42 of Set 11 | chisec
# Processing Record 43 of Set 11 | bogra
# Processing Record 44 of Set 11 | buon ma thuot
# Processing Record 45 of Set 11 | at taj
# Processing Record 46 of Set 11 | salem
# Processing Record 47 of Set 11 | namdrik
# Processing Record 48 of Set 11 | kruisfontein
# Processing Record 49 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 0 of Set 12 | mancio lima
# Processing Record 1 of Set 12 | khandyga
# Processing Record 2 of Set 12 | constitucion
# Processing Record 3 of Set 12 | malvan
# Processing Record 4 of Set 12 | donna
# Processing Record 5 of Set 12 | vingt cinq
# City not found. Skipping...
# Processing Record 6 of Set 12 | funafuti
# Processing Record 7 of Set 12 | cadale
# Processing Record 8 of Set 12 | kavieng
# Processing Record 9 of Set 12 | dinguiraye
# Processing Record 10 of Set 12 | dokshytsy
# Processing Record 11 of Set 12 | cidreira
# Processing Record 12 of Set 12 | turabah
# Processing Record 13 of Set 12 | east london
# Processing Record 14 of Set 12 | masaka
# Processing Record 15 of Set 12 | san bernardo del viento
# Processing Record 16 of Set 12 | sola
# Processing Record 17 of Set 12 | kannus
# Processing Record 18 of Set 12 | pont rouge
# Processing Record 19 of Set 12 | ada
# Processing Record 20 of Set 12 | phan thiet
# Processing Record 21 of Set 12 | sainte-marie
# Processing Record 22 of Set 12 | val-d'or
# Processing Record 23 of Set 12 | energetik
# Processing Record 24 of Set 12 | maragogi
# Processing Record 25 of Set 12 | tionk essil
# Processing Record 26 of Set 12 | shilovo
# Processing Record 27 of Set 12 | serenje
# Processing Record 28 of Set 12 | deqen
# Processing Record 29 of Set 12 | berdigestyakh
# Processing Record 30 of Set 12 | dubbo
# Processing Record 31 of Set 12 | hilo
# Processing Record 32 of Set 12 | magnitogorsk
# Processing Record 33 of Set 12 | igarka
# Processing Record 34 of Set 12 | yemetsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          562
# Lat           562
# Lng           562
# Max Temp      562
# Humidity      562
# Cloudiness    562
# Wind Speed    562
# Country       562
# Date          562
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0                    jamestown  42.0970  -79.2353     15.95        98
# 1                        ancud -41.8697  -73.8203      8.92        73
# 2  edinburgh of the seven seas -37.0676  -12.3116     18.61        92
# 3                       albany  42.6001  -73.9662     15.33        80
# 4                     rongelap  11.1635  166.8941     26.79        77
#
#    Cloudiness  Wind Speed Country        Date
# 0          75        6.69      US  1712883639
# 1           0        2.40      CL  1712883617
# 2           9        7.68      SH  1712883878
# 3         100        1.34      US  1712883645
# 4         100        8.80      MH  1712883878

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          jamestown  42.0970  -79.2353     15.95        98
# 1                              ancud -41.8697  -73.8203      8.92        73
# 2        edinburgh of the seven seas -37.0676  -12.3116     18.61        92
# 3                             albany  42.6001  -73.9662     15.33        80
# 4                           rongelap  11.1635  166.8941     26.79        77
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75        6.69      US  1712883639
# 1                 0        2.40      CL  1712883617
# 2                 9        7.68      SH  1712883878
# 3               100        1.34      US  1712883645
# 4               100        8.80      MH  1712883878

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], alpha=0.7, edgecolors="black")

# Incorporate the other graph properties
plt.grid(True)
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%Y-%m-%d")) 
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], alpha=0.7, edgecolors="black")

# Incorporate the other graph properties
plt.grid(True)
plt.title("City Max Latitude vs. Humidity (%s)" % time.strftime("%Y-%m-%d")) 
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], alpha=0.7, edgecolors="black")

# Incorporate the other graph properties
plt.grid(True)
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%Y-%m-%d"))  
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], alpha=0.7, edgecolors="black")

# Incorporate the other graph properties
plt.grid(True)
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%Y-%m-%d")) 
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, xlabel, ylabel):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=12, color="red")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                jamestown  42.0970  -79.2353     15.95        98          75
# 3                   albany  42.6001  -73.9662     15.33        80         100
# 4                 rongelap  11.1635  166.8941     26.79        77         100
# 5                 hamilton  39.1834  -84.5333     12.35        89         100
# 6        wailua homesteads  22.0669 -159.3780     23.75        86         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      US  1712883639
# 3              1.34      US  1712883645
# 4              8.80      MH  1712883878
# 5             10.29      US  1712883879
# 6              3.04      US  1712883778

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)


# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                jamestown  42.0970  -79.2353     15.95        98          75
# 3                   albany  42.6001  -73.9662     15.33        80         100
# 4                 rongelap  11.1635  166.8941     26.79        77         100
# 5                 hamilton  39.1834  -84.5333     12.35        89         100
# 6        wailua homesteads  22.0669 -159.3780     23.75        86         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.69      US  1712883639
# 3              1.34      US  1712883645
# 4              8.80      MH  1712883878
# 5             10.29      US  1712883879
# 6              3.04      US  1712883778

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                              ancud -41.8697  -73.8203      8.92        73
# 2        edinburgh of the seven seas -37.0676  -12.3116     18.61        92
# 8                      atafu village  -8.5421 -172.5159     29.81        74
# 11                          waitangi -43.9535 -176.5597     18.23        91
# 12                           kisanga  -7.4362   37.7034     23.79        95
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                 0        2.40      CL  1712883617
# 2                 9        7.68      SH  1712883878
# 8                98        4.16      TK  1712883880
# 11              100        6.26      NZ  1712883781
# 12               49        0.79      TZ  1712883881

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere: Temperature vs. Latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp")
# Out:
# The r-value is: 0.764176957985747

# %%
# Linear regression on Southern Hemisphere: Temperature vs. Latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp")
# Out:
# The r-value is: 0.5795884038955151

# %% [markdown]
# **Discussion about the linear relationship:** The r-value of Northern Hemisphere indicates the strong correlation between the Latitude and Max Temperature since it is greater than 0.7.  Max Temperature increases when the latitude increases.
# For Southern Hemisphere, the correlation is only moderate since it is between 0.5 and 0.7.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere: Humidity vs. Latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
plot_linear_regression(x_values, y_values, "Latitude", "Humidity")
# Out:
# The r-value is: 0.06871535349501887

# %%
# Linear regression on Southern Hemisphere: Humidity vs. Latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
plot_linear_regression(x_values, y_values, "Latitude", "Humidity")
# Out:
# The r-value is: 0.14119783785792717

# %% [markdown]
# **Discussion about the linear relationship:** Both Northern Hemisphere and Southern Hemisphere show none or very weak correlations between Humidity and Latitude since the r-value is less than 0.3

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere: Cloudiness vs. Latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness")
# Out:
# The r-value is: 0.0187872580252017

# %%
# Linear regression on Southern Hemisphere: Cloudiness vs. Latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness")
# Out:
# The r-value is: 0.07839358928362757

# %% [markdown]
# **Discussion about the linear relationship:** Both Northern Hemisphere and Southern Hemisphere show none or very weak correlations between Coludiness and Latitude since the r-value is less than 0.3

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere: Wind Speed vs. Latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed")
# Out:
# The r-value is: 0.02437570059821631

# %%
# Linear regression on Southern Hemisphere: Wind Speed vs. Latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed")
# Out:
# The r-value is: 0.1190368386048236

# %% [markdown]
# **Discussion about the linear relationship:** Both Northern Hemisphere and Southern Hemisphere show none or very weak correlations between Wind Speed and Latitude since the r-value is less than 0.3
